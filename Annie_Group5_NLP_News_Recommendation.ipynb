# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Import

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
import pandas as pd
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
import seaborn as sns
import json

drive.mount('/content/drive')
column_n = ['NewsId', 'Category', 'SubCat', 'Title', 'Abstract', 'url', 'TitleEnt', 'AbstractEnt']
column_b = ['ImpressionId', 'UserId', 'Time', 'History', 'Impressions']

# import the datasets
test_n_df = pd.read_csv('/content/drive/MyDrive/MSNEWS/MIND_test/news.tsv', sep='\t', header=None, names=column_n)
test_b_df = pd.read_csv('/content/drive/MyDrive/MSNEWS/MIND_test/behaviors.tsv', sep='\t', header=None, names=column_b)
train_n_df = pd.read_csv('/content/drive/MyDrive/MSNEWS/MIND_train/news.tsv', sep='\t', header=None, names=column_n)
train_b_df = pd.read_csv('/content/drive/MyDrive/MSNEWS/MIND_train/behaviors.tsv', sep='\t', header=None, names=column_b)
valid_n_df = pd.read_csv('/content/drive/MyDrive/MSNEWS/MIND_valid/news.tsv', sep='\t', header=None, names=column_n)
valid_b_df = pd.read_csv('/content/drive/MyDrive/MSNEWS/MIND_valid/behaviors.tsv', sep='\t', header=None, names=column_b)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Check the information of the datasets.

# %%
test_n_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120959 entries, 0 to 120958
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   NewsId       120959 non-null  object
#  1   Category     120959 non-null  object
#  2   SubCat       120959 non-null  object
#  3   Title        120959 non-null  object
#  4   Abstract     114256 non-null  object
#  5   url          120958 non-null  object
#  6   TitleEnt     120953 non-null  object
#  7   AbstractEnt  120950 non-null  object
# dtypes: object(8)
# memory usage: 7.4+ MB

# %%
train_n_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101527 entries, 0 to 101526
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   NewsId       101527 non-null  object
#  1   Category     101527 non-null  object
#  2   SubCat       101527 non-null  object
#  3   Title        101527 non-null  object
#  4   Abstract     96112 non-null   object
#  5   url          101527 non-null  object
#  6   TitleEnt     101524 non-null  object
#  7   AbstractEnt  101521 non-null  object
# dtypes: object(8)
# memory usage: 6.2+ MB

# %%
valid_n_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72023 entries, 0 to 72022
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NewsId       72023 non-null  object
#  1   Category     72023 non-null  object
#  2   SubCat       72023 non-null  object
#  3   Title        72023 non-null  object
#  4   Abstract     68400 non-null  object
#  5   url          72023 non-null  object
#  6   TitleEnt     72021 non-null  object
#  7   AbstractEnt  72018 non-null  object
# dtypes: object(8)
# memory usage: 4.4+ MB

# %%
test_b_df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2370727 entries, 0 to 2370726
# Data columns (total 5 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   ImpressionId  2370727 non-null  int64
#  1   UserId        2370727 non-null  object
#  2   Time          2370727 non-null  object
#  3   History       2341619 non-null  object
#  4   Impressions   2370727 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 90.4+ MB

# %%
train_b_df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2232748 entries, 0 to 2232747
# Data columns (total 5 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   ImpressionId  2232748 non-null  int64
#  1   UserId        2232748 non-null  object
#  2   Time          2232748 non-null  object
#  3   History       2186683 non-null  object
#  4   Impressions   2232748 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 85.2+ MB

# %%
valid_b_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376471 entries, 0 to 376470
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ImpressionId  376471 non-null  int64
#  1   UserId        376471 non-null  object
#  2   Time          376471 non-null  object
#  3   History       365201 non-null  object
#  4   Impressions   376471 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 14.4+ MB

# %% [markdown]
# Now, let's have a preview of our data.

# %%
test_n_df.head()
# Out:
#    NewsId   Category                    SubCat  \
# 0  N88753  lifestyle           lifestyleroyals
# 1  N45436       news  newsscienceandtechnology
# 2  N23144     health                weightloss
# 3  N86255     health                   medical
# 4  N93187       news                 newsworld
#
#                                                Title  \
# 0  The Brands Queen Elizabeth, Prince Charles, an...
# 1    Walmart Slashes Prices on Last-Generation iPads
# 2                      50 Worst Habits For Belly Fat
# 3  Dispose of unwanted prescription drugs during ...
# 4  The Cost of Trump's Aid Freeze in the Trenches...
#
#                                             Abstract  \
# 0  Shop the notebooks, jackets, and more that the...
# 1  Apple's new iPad releases bring big deals on l...
# 2  These seemingly harmless habits are holding yo...
# 3                                                NaN
# 4  Lt. Ivan Molchanets peeked over a parapet of s...
#
#                                              url  \
# 0  https://assets.msn.com/labs/mind/AAGH0ET.html
# 1  https://assets.msn.com/labs/mind/AABmf2I.html
# 2  https://assets.msn.com/labs/mind/AAB19MK.html
# 3  https://assets.msn.com/labs/mind/AAISxPN.html
# 4  https://assets.msn.com/labs/mind/AAJgNsz.html
#
#                                             TitleEnt  \
# 0  [{"Label": "Prince Philip, Duke of Edinburgh",...
# 1  [{"Label": "IPad", "Type": "J", "WikidataId": ...
# 2  [{"Label": "Adipose tissue", "Type": "C", "Wik...
# 3  [{"Label": "Drug Enforcement Administration", ...
# 4                                                 []
#
#                                          AbstractEnt
# 0                                                 []
# 1  [{"Label": "IPad", "Type": "J", "WikidataId": ...
# 2  [{"Label": "Adipose tissue", "Type": "C", "Wik...
# 3                                                 []
# 4  [{"Label": "Ukraine", "Type": "G", "WikidataId...

# %%
test_b_df.head()
# Out:
#    ImpressionId   UserId                    Time  \
# 0             1   U64099  11/19/2019 11:37:45 AM
# 1             2  U231077   11/19/2019 5:28:08 AM
# 2             3  U606012   11/19/2019 4:46:23 AM
# 3             4  U320649   11/21/2019 6:03:51 AM
# 4             5  U357840  11/22/2019 10:36:19 AM
#
#                                              History  \
# 0  N121133 N104200 N43255 N55860 N128965 N38014 N...
# 1  N45124 N84730 N45128 N104312 N70022 N99111 N26...
# 2  N59893 N84662 N90686 N33265 N127225 N120859 N6...
# 3  N110863 N7889 N86335 N85056 N115743 N63372 N19...
# 4  N98596 N85005 N15713 N67779 N47961 N55571 N666...
#
#                                          Impressions
# 0  N101071 N15647 N83400 N124838 N57092 N64623 N6...
# 1  N14657 N51253 N49521 N126571 N74286 N101071 N1...
# 2  N74286 N9250 N26898 N123737 N98301 N80580 N456...
# 3  N119559 N37657 N108085 N91287 N39136 N130190 N...
# 4  N60658 N43496 N65220 N9125 N63136 N83728 N3208...

# %% [markdown]
# Check the unique values in the columns.

# %%
test_b_df['UserId'].nunique()
# Out:
# 702005

# %%
print(test_n_df['Category'].unique(), test_n_df['SubCat'].nunique())
print(train_n_df['Category'].unique(), train_n_df['SubCat'].nunique())
print(valid_n_df['Category'].unique(), valid_n_df['SubCat'].nunique())
# Out:
# ['lifestyle' 'news' 'health' 'sports' 'weather' 'entertainment'
#  'foodanddrink' 'autos' 'travel' 'video' 'finance' 'tv' 'movies' 'music'
#  'kids' 'middleeast' 'games' 'northamerica'] 290
# ['lifestyle' 'news' 'health' 'sports' 'weather' 'entertainment'
#  'foodanddrink' 'autos' 'travel' 'video' 'finance' 'tv' 'movies' 'music'
#  'kids' 'middleeast' 'games' 'northamerica'] 285
# ['lifestyle' 'health' 'news' 'sports' 'weather' 'entertainment'
#  'foodanddrink' 'autos' 'travel' 'video' 'tv' 'finance' 'movies' 'music'
#  'kids' 'middleeast' 'games'] 269

# %%
# Check duplicates
duplicates = train_b_df.duplicated()
has = duplicates.any()
print(has)
# Out:
# False

# %% [markdown]
# ## Cleaning

# %% [markdown]
# ### Drop URL & Impression

# %% [markdown]
# Drop the columns that we will not use in our analysis.

# %%
test_n_df = test_n_df.drop('url', axis=1)
train_n_df = train_n_df.drop('url', axis=1)
valid_n_df = valid_n_df.drop('url', axis=1)

# %%
test_b_df1 = test_b_df.drop('Impressions', axis=1)
train_b_df1 = train_b_df.drop('Impressions', axis=1)
valid_b_df1 = valid_b_df.drop('Impressions', axis=1)

test_b_df1
# Out:
#          ImpressionId   UserId                    Time  \
# 0                   1   U64099  11/19/2019 11:37:45 AM
# 1                   2  U231077   11/19/2019 5:28:08 AM
# 2                   3  U606012   11/19/2019 4:46:23 AM
# 3                   4  U320649   11/21/2019 6:03:51 AM
# 4                   5  U357840  11/22/2019 10:36:19 AM
# ...               ...      ...                     ...
# 2370722       2370723  U584874   11/21/2019 6:35:29 AM
# 2370723       2370724  U584857   11/22/2019 7:13:47 AM
# 2370724       2370725  U160629  11/20/2019 10:38:57 PM
# 2370725       2370726  U406290   11/21/2019 8:24:26 AM
# 2370726       2370727  U268599   11/18/2019 8:07:46 AM
#
#                                                    History
# 0        N121133 N104200 N43255 N55860 N128965 N38014 N...
# 1        N45124 N84730 N45128 N104312 N70022 N99111 N26...
# 2        N59893 N84662 N90686 N33265 N127225 N120859 N6...
# 3        N110863 N7889 N86335 N85056 N115743 N63372 N19...
# 4        N98596 N85005 N15713 N67779 N47961 N55571 N666...
# ...                                                    ...
# 2370722          N72571 N14240 N26193 N82055 N23920 N41710
# 2370723  N57191 N54360 N1596 N61590 N104737 N71977 N773...
# 2370724  N105366 N51167 N66294 N71092 N92463 N38171 N11...
# 2370725  N55903 N85484 N12015 N121551 N65119 N15471 N11...
# 2370726  N9740 N65259 N112324 N29153 N59111 N54723 N343...
#
# [2370727 rows x 4 columns]

# %% [markdown]
# ### Take sample on Users

# %% [markdown]
# Since we have a very large dataset, we would take a sample on users to study their behaviors.

# %%
unique_users = test_b_df1['UserId'].unique()
sampled_users = pd.Series(unique_users).sample(frac=0.01, random_state=42)
sampled_test = test_b_df1[test_b_df1['UserId'].isin(sampled_users)]

sampled_test
# Out:
#          ImpressionId   UserId                    Time  \
# 7                   8   U84394   11/18/2019 1:43:17 PM
# 52                 53  U571456   11/22/2019 7:18:21 PM
# 54                 55  U335328   11/16/2019 4:47:52 PM
# 58                 59   U66995  11/19/2019 12:18:41 PM
# 158               159  U524661   11/22/2019 9:52:11 AM
# ...               ...      ...                     ...
# 2370487       2370488  U606058   11/17/2019 9:45:53 PM
# 2370491       2370492  U666365   11/17/2019 7:41:26 AM
# 2370493       2370494   U76422   11/20/2019 5:02:05 PM
# 2370651       2370652  U217845  11/21/2019 11:17:57 AM
# 2370713       2370714  U838401   11/21/2019 8:04:56 AM
#
#                                                    History
# 7        N54656 N128643 N92838 N106692 N50914 N119997 N...
# 52       N118005 N86208 N82746 N90939 N52435 N98214 N97...
# 54       N62205 N35278 N13996 N65757 N90507 N109238 N94...
# 58       N63092 N85659 N65119 N73122 N51724 N120705 N45...
# 158      N77001 N128643 N112196 N98238 N130269 N85056 N...
# ...                                                    ...
# 2370487  N41122 N39472 N4833 N9740 N65259 N5128 N19474 ...
# 2370491  N39472 N86208 N82753 N76065 N121944 N114156 N3...
# 2370493  N102357 N21710 N9276 N86141 N51893 N93049 N127...
# 2370651  N23891 N9375 N63676 N87446 N121551 N130260 N49...
# 2370713                                       N9191 N38820
#
# [23888 rows x 4 columns]

# %%
print(sampled_test['UserId'].nunique(), test_b_df1['UserId'].nunique())
# Out:
# 7020 702005

# %% [markdown]
# ### Split History

# %% [markdown]
# To better understand the user behaviors, we explode the 'History' column.

# %%
sampled_test['History'] = sampled_test['History'].str.split(' ')
exploded_test = sampled_test.explode('History')

# %%
exploded_test.info(null_counts=True)
exploded_test.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1009992 entries, 7 to 2370713
# Data columns (total 4 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   ImpressionId  1009992 non-null  int64
#  1   UserId        1009992 non-null  object
#  2   Time          1009992 non-null  object
#  3   History       1009682 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 38.5+ MB
#    ImpressionId  UserId                   Time  History
# 7             8  U84394  11/18/2019 1:43:17 PM   N54656
# 7             8  U84394  11/18/2019 1:43:17 PM  N128643
# 7             8  U84394  11/18/2019 1:43:17 PM   N92838
# 7             8  U84394  11/18/2019 1:43:17 PM  N106692
# 7             8  U84394  11/18/2019 1:43:17 PM   N50914

# %% [markdown]
# # EDA

# %% [markdown]
# To better understand the datasets, we will explore some of the features.

# %% [markdown]
# ## Time Analysis

# %% [markdown]
# To understand at what time the users would like to read news the most, we add a column of 'Time_of_Day' by splitting time into four time frames, and study the user behaviors.

# %%
sampled_test['Time'] = pd.to_datetime(sampled_test['Time'])

def assign_time_of_day(hour):
    if 6 <= hour <= 11:
        return 'morning'
    elif 12 <= hour <= 17:
        return 'afternoon'
    elif 18 <= hour <= 23:
        return 'evening'
    else:
        return 'night'

sampled_test['Time_of_Day'] = sampled_test['Time'].dt.hour.apply(lambda x: assign_time_of_day(x))

# %%
sampled_test.head()
# Out:
#      ImpressionId   UserId                Time  \
# 7               8   U84394 2019-11-18 13:43:17
# 52             53  U571456 2019-11-22 19:18:21
# 54             55  U335328 2019-11-16 16:47:52
# 58             59   U66995 2019-11-19 12:18:41
# 158           159  U524661 2019-11-22 09:52:11
#
#                                                History Time_of_Day
# 7    [N54656, N128643, N92838, N106692, N50914, N11...   afternoon
# 52   [N118005, N86208, N82746, N90939, N52435, N982...     evening
# 54   [N62205, N35278, N13996, N65757, N90507, N1092...   afternoon
# 58   [N63092, N85659, N65119, N73122, N51724, N1207...   afternoon
# 158  [N77001, N128643, N112196, N98238, N130269, N8...     morning

# %%
# Count the value of each time frame
sampled_test['Time_of_Day'].value_counts()
# Out:
# morning      10667
# afternoon     7803
# night         3036
# evening       2382
# Name: Time_of_Day, dtype: int64

# %%
# Check the time range of the dataset
earliest = sampled_test['Time'].min()
latest = sampled_test['Time'].max()
print(earliest, latest)
# Out:
# 2019-11-16 00:11:42 2019-11-22 23:51:50

# %%
# Calculate the time proportion
sampled_test['Time_of_Day'].value_counts() / len(sampled_test)
# Out:
# morning      0.446542
# afternoon    0.326649
# night        0.127093
# evening      0.099715
# Name: Time_of_Day, dtype: float64

# %% [markdown]
# To visualize the time the users like to read news the most, we can draw a seaborn plot.

# %%
# Simiao contributed to the visual improvement of this plot
# Visualize using seaborn
sns.set_style('whitegrid')
sns.set_palette('pastel')

time = sampled_test.copy()
time['Time_of_Day'] = time['Time_of_Day'].replace({'morning': 'Morning', 'afternoon': 'Afternoon', 'evening': 'Evening', 'night': 'Night'})
T = sns.catplot(x="Time_of_Day", kind="count", data=time, order=time['Time_of_Day'].value_counts().index, height=5, aspect=1)

for ay in T.axes.flat:
    ay.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))

T.set(title='Counts of News Read by Time of Day', xlabel='Time of Day', ylabel='Count')
plt.show()

# %% [markdown]
# ## Popular Entities

# %% [markdown]
# To understand what entities are the most popular among all the news we have in the dataset, we will clean the 'TitleEnt' column to look into the frequency of each entity.

# %%
# Create a new column of Labels
def extract_labels(row):
    try:
        if pd.notnull(row) and isinstance(row, str):
            objects = json.loads(row)
            labels = [obj['Label'].replace(" ", "_").replace(",", "_") for obj in objects]
            return labels
        else:
            return []
    except Exception as e:
        return []

test_n_df['Labels'] = test_n_df['TitleEnt'].apply(extract_labels)
test_n_df.head()
# Out:
#    NewsId   Category                    SubCat  \
# 0  N88753  lifestyle           lifestyleroyals
# 1  N45436       news  newsscienceandtechnology
# 2  N23144     health                weightloss
# 3  N86255     health                   medical
# 4  N93187       news                 newsworld
#
#                                                Title  \
# 0  The Brands Queen Elizabeth, Prince Charles, an...
# 1    Walmart Slashes Prices on Last-Generation iPads
# 2                      50 Worst Habits For Belly Fat
# 3  Dispose of unwanted prescription drugs during ...
# 4  The Cost of Trump's Aid Freeze in the Trenches...
#
#                                             Abstract  \
# 0  Shop the notebooks, jackets, and more that the...
# 1  Apple's new iPad releases bring big deals on l...
# 2  These seemingly harmless habits are holding yo...
# 3                                                NaN
# 4  Lt. Ivan Molchanets peeked over a parapet of s...
#
#                                             TitleEnt  \
# 0  [{"Label": "Prince Philip, Duke of Edinburgh",...
# 1  [{"Label": "IPad", "Type": "J", "WikidataId": ...
# 2  [{"Label": "Adipose tissue", "Type": "C", "Wik...
# 3  [{"Label": "Drug Enforcement Administration", ...
# 4                                                 []
#
#                                          AbstractEnt  \
# 0                                                 []
# 1  [{"Label": "IPad", "Type": "J", "WikidataId": ...
# 2  [{"Label": "Adipose tissue", "Type": "C", "Wik...
# 3                                                 []
# 4  [{"Label": "Ukraine", "Type": "G", "WikidataId...
#
#                                               Labels
# 0  [Prince_Philip__Duke_of_Edinburgh, Charles__Pr...
# 1                                    [IPad, Walmart]
# 2                                   [Adipose_tissue]
# 3                  [Drug_Enforcement_Administration]
# 4                                                 []

# %%
test_n_df1 = test_n_df.explode('Labels')
test_n_df1
# Out:
#          NewsId   Category                    SubCat  \
# 0        N88753  lifestyle           lifestyleroyals
# 0        N88753  lifestyle           lifestyleroyals
# 0        N88753  lifestyle           lifestyleroyals
# 1        N45436       news  newsscienceandtechnology
# 1        N45436       news  newsscienceandtechnology
# ...         ...        ...                       ...
# 120954   N30717     travel             travelarticle
# 120955   N56897     sports           basketball_ncaa
# 120956  N108404      video                      news
# 120957   N74617      autos               autossports
# 120958   N56840     sports               more_sports
#
#                                                     Title  \
# 0       The Brands Queen Elizabeth, Prince Charles, an...
# 0       The Brands Queen Elizabeth, Prince Charles, an...
# 0       The Brands Queen Elizabeth, Prince Charles, an...
# 1         Walmart Slashes Prices on Last-Generation iPads
# 1         Walmart Slashes Prices on Last-Generation iPads
# ...                                                   ...
# 120954  Perfect North Slopes purchases bankrupt West V...
# 120955  Arizona Wildcats basketball dismisses Devonair...
# 120956  Concerns continue to grow over Trump's busines...
# 120957                  Best Sports Car Deals for October
# 120958       Shall we dance: Sports stars shake their leg
#
#                                                  Abstract  \
# 0       Shop the notebooks, jackets, and more that the...
# 0       Shop the notebooks, jackets, and more that the...
# 0       Shop the notebooks, jackets, and more that the...
# 1       Apple's new iPad releases bring big deals on l...
# 1       Apple's new iPad releases bring big deals on l...
# ...                                                   ...
# 120954  Perfect North Slopes is expanding its reach wi...
# 120955  Arizona basketball coach Sean Miller announced...
# 120956  After Kentucky Governor Matt Bevin spent two n...
# 120957                                                NaN
# 120958                                                NaN
#
#                                                  TitleEnt  \
# 0       [{"Label": "Prince Philip, Duke of Edinburgh",...
# 0       [{"Label": "Prince Philip, Duke of Edinburgh",...
# 0       [{"Label": "Prince Philip, Duke of Edinburgh",...
# 1       [{"Label": "IPad", "Type": "J", "WikidataId": ...
# 1       [{"Label": "IPad", "Type": "J", "WikidataId": ...
# ...                                                   ...
# 120954  [{"Label": "Perfect North Slopes", "Type": "S"...
# 120955  [{"Label": "Arizona Wildcats", "Type": "U", "W...
# 120956  [{"Label": "Donald Trump", "Type": "P", "Wikid...
# 120957  [{"Label": "Peugeot RCZ", "Type": "V", "Wikida...
# 120958                                                 []
#
#                                               AbstractEnt  \
# 0                                                      []
# 0                                                      []
# 0                                                      []
# 1       [{"Label": "IPad", "Type": "J", "WikidataId": ...
# 1       [{"Label": "IPad", "Type": "J", "WikidataId": ...
# ...                                                   ...
# 120954  [{"Label": "Perfect North Slopes", "Type": "S"...
# 120955  [{"Label": "Sean Miller", "Type": "P", "Wikida...
# 120956  [{"Label": "Citizens for Responsibility and Et...
# 120957                                                 []
# 120958                                                 []
#
#                                   Labels
# 0       Prince_Philip__Duke_of_Edinburgh
# 0               Charles__Prince_of_Wales
# 0                           Elizabeth_II
# 1                                   IPad
# 1                                Walmart
# ...                                  ...
# 120954                     West_Virginia
# 120955                  Arizona_Wildcats
# 120956                      Donald_Trump
# 120957                       Peugeot_RCZ
# 120958                               NaN
#
# [175448 rows x 8 columns]

# %%
count_labels = test_n_df1['Labels'].value_counts()
n = 20
top_labels = count_labels.head(n)
print(top_labels)
# Out:
# Donald_Trump                        2909
# National_Football_League            1174
# New_England_Patriots                1072
# Houston_Astros                       808
# United_States                        739
# California                           734
# Cleveland_Browns                     647
# Philadelphia_Eagles                  603
# Pittsburgh_Steelers                  594
# Republican_Party_(United_States)     584
# Dallas_Cowboys                       578
# Florida                              571
# New_York_Yankees                     566
# Democratic_Party_(United_States)     565
# Houston_Texans                       547
# Ukraine                              534
# Baltimore_Ravens                     520
# Indianapolis_Colts                   516
# Halloween                            514
# Detroit_Lions                        495
# Name: Labels, dtype: int64

# %% [markdown]
# ## Popular News Category

# %% [markdown]
# To understand what news category is the most popular, let's check how many news each category contains in our dataset.

# %%
cat = test_n_df.copy()
cat['Category'] = cat['Category'].replace({
    'sports': 'Sports','news': 'News', 'finance': 'Finance', 'travel': 'Travel', 'video': 'Video', 'lifestyle': 'Lifestyle', 'foodanddrink': 'Food and Drink',
    'weather': 'Weather', 'autos': 'Autos', 'health': 'Health', 'music': 'Music', 'tv': 'TV', 'entertainment': 'Entertainment', 'movies': 'Movies',
    'kids': 'Kids', 'middleeast': 'Middle East', 'games': 'Games', 'northamerica': 'North America'})

cat_plot = sns.catplot(y='Category', kind='count', data=cat, order=cat['Category'].value_counts().index, height=6, aspect=1.5)

cat_plot.set(title='News Category by Count', xlabel='Counts', ylabel='News Category')
plt.show()

# %% [markdown]
# It seems like most of the categories our dataset contains is Sports and News, exceeding 35,000. On the other hand, we do not have much Kids, Middle East, Games, and North America categories.

# %% [markdown]
# To explore what topics make Sports such a big category, let's take a look into Sports's subcategories.

# %%
cat_sports = cat[cat['Category'] == 'Sports']
cat_sports['SubCat'].value_counts().head(5)
# Out:
# football_nfl      14211
# football_ncaa      4155
# baseball_mlb       4001
# basketball_nba     3841
# more_sports        3271
# Name: SubCat, dtype: int64

# %% [markdown]
# In the Sports category, football_nfl is the most popular subcategory, aligning with the most frequent entity we just discovered.

# %% [markdown]
# Then, to understand what categories the users like to read, we check the categories in each user's history, and count what category appears the most frequently.

# %%
cat_hist = pd.merge(exploded_test, test_n_df, left_on = 'History', right_on = 'NewsId', how = 'left')
cat_hist = cat_hist[['ImpressionId', 'UserId', 'History', 'Category', 'SubCat', 'Title']]
cat_hist.head()
# Out:
#    ImpressionId  UserId  History Category             SubCat  \
# 0             8  U84394   N54656   movies          movienews
# 1             8  U84394  N128643       tv       tv-celebrity
# 2             8  U84394   N92838    video          lifestyle
# 3             8  U84394  N106692  finance  finance-companies
# 4             8  U84394   N50914   health             voices
#
#                                                Title
# 0  'Joker' Continues to Smash Box Office Expectat...
# 1  Miguel Cervantes' Wife Reveals Daughter, 3, 'D...
# 2  All-female Delta crew flies 120 girls to NASA ...
# 3  Yahoo data breach $117.5 million settlement: G...
# 4  My Father's Battle With Alzheimer's Revealed a...

# %%
cat_hist['Category'] = cat_hist['Category'].replace({
    'sports': 'Sports','news': 'News', 'finance': 'Finance', 'travel': 'Travel', 'video': 'Video', 'lifestyle': 'Lifestyle', 'foodanddrink': 'Food and Drink',
    'weather': 'Weather', 'autos': 'Autos', 'health': 'Health', 'music': 'Music', 'tv': 'TV', 'entertainment': 'Entertainment', 'movies': 'Movies',
    'kids': 'Kids', 'middleeast': 'Middle East', 'games': 'Games', 'northamerica': 'North America'})

hist_plot = sns.catplot(y='Category', kind='count', data=cat_hist, order=cat_hist['Category'].value_counts().index, height=6, aspect=1.5)

hist_plot.set(title='History News Category by Count', xlabel='Counts', ylabel='News Category')
plt.show()

# %% [markdown]
# It seems like among the users we have in the sample, News is the most popular category that they would like to read. Following are Sorts, Lifestyle, Finance, and TV. Middle East, Kids, and Games have almost no count because we do not have much of them in the dataset. North America even disappear from the graph.

# %% [markdown]
# # TF-IDF
#
# To perform clustering, we may first transform our text into vectors by combining the news dataset and behavior dataset and applying the TF-IDF measure.

# %%
# Merging news and behavior datasets

test_n_df['NewsId'] = test_n_df['NewsId'].astype(str)
exploded_test['History'] = exploded_test['History'].astype(str)

merged_df = pd.merge(test_n_df, exploded_test, left_on='NewsId', right_on='History')

print(merged_df.shape)
print(merged_df.head())
# Out:
# (1009664, 12)
#    NewsId Category     SubCat  \
# 0  N93187     news  newsworld
# 1  N93187     news  newsworld
# 2  N93187     news  newsworld
# 3  N93187     news  newsworld
# 4  N93187     news  newsworld
#
#                                                Title  \
# 0  The Cost of Trump's Aid Freeze in the Trenches...
# 1  The Cost of Trump's Aid Freeze in the Trenches...
# 2  The Cost of Trump's Aid Freeze in the Trenches...
# 3  The Cost of Trump's Aid Freeze in the Trenches...
# 4  The Cost of Trump's Aid Freeze in the Trenches...
#
#                                             Abstract TitleEnt  \
# 0  Lt. Ivan Molchanets peeked over a parapet of s...       []
# 1  Lt. Ivan Molchanets peeked over a parapet of s...       []
# 2  Lt. Ivan Molchanets peeked over a parapet of s...       []
# 3  Lt. Ivan Molchanets peeked over a parapet of s...       []
# 4  Lt. Ivan Molchanets peeked over a parapet of s...       []
#
#                                          AbstractEnt Labels  ImpressionId  \
# 0  [{"Label": "Ukraine", "Type": "G", "WikidataId...     []         72674
# 1  [{"Label": "Ukraine", "Type": "G", "WikidataId...     []         79865
# 2  [{"Label": "Ukraine", "Type": "G", "WikidataId...     []        134526
# 3  [{"Label": "Ukraine", "Type": "G", "WikidataId...     []        163576
# 4  [{"Label": "Ukraine", "Type": "G", "WikidataId...     []        179921
#
#     UserId                    Time History
# 0  U449350   11/16/2019 6:19:10 PM  N93187
# 1  U149703   11/18/2019 9:23:26 AM  N93187
# 2  U449350   11/19/2019 9:22:29 AM  N93187
# 3  U449350  11/22/2019 12:14:12 PM  N93187
# 4  U110457   11/22/2019 6:26:37 PM  N93187

# %% [markdown]
# To transform what we have into vectors, we may take a smaller sample.

# %%
sampled_df = merged_df.sample(frac=0.01, random_state = 42)
print(sampled_df.shape)
print(sampled_df.head())
# Out:
# (10097, 12)
#          NewsId      Category             SubCat  \
# 479255  N116725         music    music-celebrity
# 871546   N25751       weather  weathertopstories
# 232147   N68153          news       newspolitics
# 23759    N24115     lifestyle      shop-holidays
# 376817   N96437  foodanddrink           foodnews
#
#                                                     Title  \
# 479255  Justin Bieber Reveals Where He Stands With Tay...
# 871546  This Arctic blast is in its final day. But the...
# 232147  Are Democrats Willing to Pay More in Taxes for...
# 23759   100+ Funny White Elephant Gifts That'll Leave ...
# 376817  Rachael Ray finally opens restaurant with no p...
#
#                                                  Abstract  \
# 479255  The two performers have not seen eye to eye in...
# 871546  The hundreds of millions of people gripped by ...
# 232147  Senator Elizabeth Warren has surged to the fro...
# 23759                                 The pressure is on!
# 376817  Rachael Ray is the anomaly among TV celebrity ...
#
#                                                  TitleEnt  \
# 479255  [{"Label": "Justin Bieber", "Type": "P", "Wiki...
# 871546                                                 []
# 232147  [{"Label": "Single-payer healthcare", "Type": ...
# 23759   [{"Label": "Christmas and holiday season", "Ty...
# 376817                                                 []
#
#                                               AbstractEnt  \
# 479255                                                 []
# 871546                                                 []
# 232147  [{"Label": "Single-payer healthcare", "Type": ...
# 23759                                                  []
# 376817                                                 []
#
#                                                    Labels  ImpressionId  \
# 479255       [Justin_Bieber, Scooter_Braun, Taylor_Swift]        915141
# 871546                                                 []       2100952
# 232147  [Single-payer_healthcare, Democratic_Party_(Un...        406202
# 23759   [Christmas_and_holiday_season, White_elephant_...       1258045
# 376817                                                 []        563166
#
#          UserId                   Time  History
# 479255   U71331  11/16/2019 6:12:47 PM  N116725
# 871546  U238095  11/21/2019 4:26:34 AM   N25751
# 232147  U158749  11/21/2019 8:38:36 AM   N68153
# 23759   U483927  11/21/2019 2:41:25 PM   N24115
# 376817  U111650  11/22/2019 7:33:09 PM   N96437

# %%
# Perform the TF-IDF measure
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words='english')
text_vectors = tfidf.fit_transform(sampled_df['Title'])

print(tfidf.vocabulary_)
# Out:
# {'justin': 4839, 'bieber': 1077, 'reveals': 7355, 'stands': 8283, 'taylor': 8688, 'swift': 8601, 'scooter': 7679, 'braun': 1296, 'drama': 2895, 'arctic': 678, 'blast': 1131, 'final': 3475, 'day': 2443, 'cold': 1949, 'isn': 4689, 'quite': 6950, 'democrats': 2579, 'willing': 9591, 'pay': 6390, 'taxes': 8686, 'medicare': 5561, '100': 4, 'funny': 3717, 'white': 9560, 'elephant': 3060, 'gifts': 3811, 'll': 5239, 'leave': 5122, 'laughing': 5070, 'hard': 4093, 'holiday': 4286, 'season': 7715, 'rachael': 6959, 'ray': 7043, 'finally': 3479, 'opens': 6161, 'restaurant': 7310, 'physical': 6493, 'location': 5252, 'kelly': 4877, 'ripa': 7417, 'responds': 7305, 'backlash': 847, 'son': 8128, 'extreme': 3300, 'poverty': 6696, 'joke': 4795, 'kentucky': 4885, 'man': 5408, 'dies': 2691, 'trying': 9093, 'save': 7622, 'sons': 8134, 'florida': 3569, 'rip': 7416, 'current': 2358, 'family': 3350, 'trip': 9063, 'husband': 4400, '102': 9, 'years': 9724, 'old': 6133, 'marriage': 5459, 'like': 5190, 'haunted': 4130, 'place': 6548, 'state': 8297, 'don': 2847, 'visit': 9394, 'country': 2220, 'music': 5880, 'icon': 4422, 'alan': 468, 'jackson': 4708, 'brings': 1344, '2020': 110, 'tour': 8952, 'south': 8157, 'carolina': 1589, 'multiple': 5864, 'houses': 4356, 'plane': 6556, 'crashes': 2267, 'nj': 6014, 'fast': 3372, 'food': 3595, 'restaurants': 7311, 'wish': 9622, 'world': 9659, 'largest': 5052, 'superyachts': 8514, 'glamorous': 3835, 'display': 2774, 'boat': 1177, 'kicks': 4910, 'woman': 9636, 'allegedly': 504, 'fakes': 3337, 'cancer': 1530, 'receives': 7090, '10': 3, '000': 0, 'donations': 2854, 'hikers': 4249, 'mystery': 5892, 'skeleton': 7980, 'remote': 7218, 'mountain': 5835, 'california': 1493, 'miranda': 5718, 'lambert': 5029, 'says': 7633, 'terrified': 8756, 'gym': 4021, 'tbh': 8690, 'relate': 7185, 'burning': 1435, 'questions': 6941, 'cowboys': 2241, 'vs': 9416, 'giants': 3807, 'monday': 5786, 'night': 6002, 'football': 3601, 'flight': 3549, 'shaming': 7830, 'gaining': 3738, 'traction': 8975, 'cost': 2203, 'airlines': 454, 'billions': 1090, 'jury': 4833, 'convicts': 2147, 'killing': 4923, 'wife': 9575, 'month': 5800, 'diagnosed': 2673, 'terminal': 8748, 'illness': 4450, 'kristen': 4994, 'stewart': 8342, 'planning': 6562, 'propose': 6847, 'girlfriend': 3823, 'plus': 6600, 'celeb': 1654, 'love': 5311, 'life': 5181, 'news': 5983, 'early': 2982, 'november': 6050, '2019': 109, 'advocated': 408, 'caning': 1540, 'adultery': 395, 'gets': 3798, 'caned': 1537, 'joe': 4784, 'biden': 1075, 'reportedly': 7259, 'denied': 2591, 'communion': 2011, 'church': 1832, 'stance': 8277, 'abortion': 286, 'favorite': 3387, '90s': 263, 'stars': 8289, 'doing': 2832, 'today': 8903, 'lance': 5035, 'altimeter': 525, 'delicious': 2556, 'drop': 2929, 'truck': 9077, 'camper': 1519, 'debuting': 2477, 'sema': 7761, 'boomers': 1228, 'make': 5389, 'critical': 2299, 'retirement': 7333, 'mistake': 5744, 'photos': 6489, 'came': 1508, 'trump': 9086, 'tariffs': 8669, 'haven': 4133, 'revitalized': 7364, 'american': 547, 'steelmakers': 8323, 'saved': 7623, '36': 163, 'quit': 6949, 'jobs': 4783, 'travel': 9023, 'offbeat': 6102, 'ways': 9492, 'cut': 2367, 'costs': 2208, 'jersey': 4757, 'shore': 7892, 'cast': 1616, 'celebrates': 1656, 'angelina': 578, 'pivarnick': 6542, 'bachelorette': 843, 'new': 5976, 'orleans': 6203, 'reporter': 7260, 'stop': 8363, 'cat': 1624, 'interrupts': 4629, 'segment': 7746, 'chicago': 1782, 'creates': 2277, 'stir': 8351, 'arrives': 705, 'anchor': 567, 'calls': 1499, 'body': 1184, 'comments': 1999, 'told': 8912, 'looks': 5279, 'mighty': 5667, 'big': 1079, 'tv': 9129, 'artist': 713, 'reimagined': 7174, 'disney': 2770, 'princesses': 6779, 'horror': 4332, 'movie': 5848, 'villains': 9373, 'scary': 7651, 'good': 3872, '20': 96, 'stocks': 8356, 'double': 2871, 'money': 5788, 'lots': 5298, 'tears': 8707, 'teresa': 8746, 'giudice': 3825, 'details': 2649, 'reuniting': 7350, 'italy': 4695, 'cheese': 1760, 'named': 5900, 'best': 1050, 'time': 8880, 'wedding': 9507, 'photo': 6483, ' ...

# %%
print(text_vectors)
# Out:
#   (0, 2895)	0.35821086507887445
#   (0, 1296)	0.38445479274380273
#   (0, 7679)	0.38445479274380273
#   (0, 8601)	0.34179242092819345
#   (0, 8688)	0.29509125409145487
#   (0, 8283)	0.320380092306319
#   (0, 7355)	0.2554033666594593
#   (0, 1077)	0.33540315010334165
#   (0, 4839)	0.3029909853781533
#   (1, 6950)	0.42267485942988886
#   (1, 4689)	0.3469233812906121
#   (1, 1949)	0.372605855839111
#   (1, 2443)	0.27846847785653167
#   (1, 3475)	0.41048159490874936
#   (1, 1131)	0.3975645695957146
#   (1, 678)	0.3975645695957146
#   (2, 5561)	0.5033564040906842
#   (2, 8686)	0.4474996987708595
#   (2, 6390)	0.3879567793956578
#   (2, 9591)	0.4926983617152742
#   (2, 2579)	0.3912981110929614
#   (3, 7715)	0.24333942074130752
#   (3, 4286)	0.2845475660161722
#   (3, 4093)	0.2867822782515858
#   (3, 5070)	0.3407923087288082
#   :	:
#   (10094, 14)	0.39592903045201694
#   (10094, 9118)	0.367122621130853
#   (10094, 7966)	0.35784902865754514
#   (10094, 3349)	0.30461487334307835
#   (10094, 5544)	0.3250816365481381
#   (10094, 5948)	0.2512526474684801
#   (10094, 1462)	0.2589577947886091
#   (10094, 8791)	0.2704036037687298
#   (10094, 8825)	0.2597346185999657
#   (10094, 6983)	0.33342128266424237
#   (10095, 5924)	0.44875219231723734
#   (10095, 1328)	0.38887715380109555
#   (10095, 3192)	0.4135406891528696
#   (10095, 8489)	0.4203240119244382
#   (10095, 5191)	0.3371343680981427
#   (10095, 8650)	0.35565804172485116
#   (10095, 7631)	0.24404021750575647
#   (10096, 4595)	0.39408443491429923
#   (10096, 8131)	0.3773369332474197
#   (10096, 7957)	0.3410897360898641
#   (10096, 1942)	0.3706905684744548
#   (10096, 2380)	0.3484771636769872
#   (10096, 5680)	0.3484771636769872
#   (10096, 7193)	0.4051911373130331
#   (10096, 5976)	0.20373528505930752

# %%
text_vectors.shape
# Out:
# (10097, 9764)
